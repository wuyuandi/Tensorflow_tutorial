# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

mnist = input_data.read_data_sets("MNIST_data",one_hot=True)


batch_size = 100

n_batch = mnist.train.num_examples // batch_size

x = tf.placeholder(tf.float32,[None,784])
y = tf.placeholder(tf.float32,[None,10])

W = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))
prediction = tf.nn.softmax(tf.matmul(x,W)+b)


loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y,logits=prediction))
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)


init = tf.global_variables_initializer()

#argmax返回一维张量中最大的值所在的位置
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))


accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(50):
        for batch in range(n_batch):
            batch_xs,batch_ys =  mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys})
        
        acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Iter " + str(epoch) + ",Testing Accuracy " + str(acc))
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Iter 0,Testing Accuracy 0.7352
# Iter 1,Testing Accuracy 0.7285
# Iter 2,Testing Accuracy 0.7369
# Iter 3,Testing Accuracy 0.7481
# Iter 4,Testing Accuracy 0.7438
# Iter 5,Testing Accuracy 0.7323
# Iter 6,Testing Accuracy 0.7394
# Iter 7,Testing Accuracy 0.7457
# Iter 8,Testing Accuracy 0.7574
# Iter 9,Testing Accuracy 0.7529
# Iter 10,Testing Accuracy 0.8785
# Iter 11,Testing Accuracy 0.8787
# Iter 12,Testing Accuracy 0.8961
# Iter 13,Testing Accuracy 0.8986
# Iter 14,Testing Accuracy 0.8886
# Iter 15,Testing Accuracy 0.8959
# Iter 16,Testing Accuracy 0.906
# Iter 17,Testing Accuracy 0.9003
# Iter 18,Testing Accuracy 0.9105
# Iter 19,Testing Accuracy 0.9113
# Iter 20,Testing Accuracy 0.8886
# Iter 21,Testing Accuracy 0.9071
# Iter 22,Testing Accuracy 0.9058
# Iter 23,Testing Accuracy 0.9099
# Iter 24,Testing Accuracy 0.8982
# Iter 25,Testing Accuracy 0.9043
# Iter 26,Testing Accuracy 0.9155
# Iter 27,Testing Accuracy 0.9147
# Iter 28,Testing Accuracy 0.9175
# Iter 29,Testing Accuracy 0.9165
# Iter 30,Testing Accuracy 0.9094
# Iter 31,Testing Accuracy 0.9146
# Iter 32,Testing Accuracy 0.9181
# Iter 33,Testing Accuracy 0.9073
# Iter 34,Testing Accuracy 0.9095
# Iter 35,Testing Accuracy 0.9041
# Iter 36,Testing Accuracy 0.9079
# Iter 37,Testing Accuracy 0.9152
# Iter 38,Testing Accuracy 0.9166
# Iter 39,Testing Accuracy 0.917
# Iter 40,Testing Accuracy 0.91
# Iter 41,Testing Accuracy 0.9161
# Iter 42,Testing Accuracy 0.9148
# Iter 43,Testing Accuracy 0.9161
# Iter 44,Testing Accuracy 0.9193
# Iter 45,Testing Accuracy 0.9121
# Iter 46,Testing Accuracy 0.9138
# Iter 47,Testing Accuracy 0.9143
# Iter 48,Testing Accuracy 0.9197
# Iter 49,Testing Accuracy 0.9109
